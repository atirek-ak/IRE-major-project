# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("time_frame.csv")

# %%
data.iloc[:,3:-1]
# Out:
#               1        2        3        4        5        6        7  \
# 0       4740.00  4740.00  4739.90  4738.59  4736.09  4735.10  4736.08
# 1       4740.00  4739.90  4738.59  4736.09  4735.10  4736.08  4736.09
# 2       4739.90  4738.59  4736.09  4735.10  4736.08  4736.09  4739.86
# 3       4738.59  4736.09  4735.10  4736.08  4736.09  4739.86  4739.88
# 4       4736.09  4735.10  4736.08  4736.09  4739.86  4739.88  4739.89
# ...         ...      ...      ...      ...      ...      ...      ...
# 130975  9406.41  9417.48  9474.99  9473.00  9473.00  9473.00  9472.00
# 130976  9417.48  9474.99  9473.00  9473.00  9473.00  9472.00  9484.00
# 130977  9474.99  9473.00  9473.00  9473.00  9472.00  9484.00  9488.00
# 130978  9473.00  9473.00  9473.00  9472.00  9484.00  9488.00  9487.95
# 130979  9473.00  9473.00  9472.00  9484.00  9488.00  9487.95  9488.99
#
#               8        9       10  ...       51       52       53       54  \
# ...

# %%
num_data=data.to_numpy()

# %%
new=num_data[:,3:-1]

# %%
new.shape
# Out:
# (130980, 60)

# %%
meaan=np.arange(new.shape[0])
lis=[]

# %%
for i in new:
    lis.append(i.mean())

# %%
# lis

# %%
for i in range(data.iloc[:,-1].shape[0]):
        if(data.iloc[:,-1][i]==lis[i]):
            data.iloc[:,-1][i]=0
        elif(data.iloc[:,-1][i]>lis[i]):
            data.iloc[:,-1][i]=1
        else:
            data.iloc[:,-1][i]=-1
# Out:
# /home/pulkit/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /home/pulkit/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/pulkit/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data
# Out:
#         Unnamed: 0            Timestamp  polarity        1        2        3  \
# 0                0  2017-09-01 01:00:00  0.095204  4740.00  4740.00  4739.90
# 1                1  2017-09-01 01:01:00  0.095204  4740.00  4739.90  4738.59
# 2                2  2017-09-01 01:02:00  0.095204  4739.90  4738.59  4736.09
# 3                3  2017-09-01 01:03:00  0.095204  4738.59  4736.09  4735.10
# 4                4  2017-09-01 01:04:00  0.095204  4736.09  4735.10  4736.08
# ...            ...                  ...       ...      ...      ...      ...
# 130975      130975  2017-11-30 23:55:00  0.094750  9406.41  9417.48  9474.99
# 130976      130976  2017-11-30 23:56:00  0.094750  9417.48  9474.99  9473.00
# 130977      130977  2017-11-30 23:57:00  0.094750  9474.99  9473.00  9473.00
# 130978      130978  2017-11-30 23:58:00  0.094750  9473.00  9473.00  9473.00
# 130979      130979  2017-11-30 23:59:00  0.094750  9473.00  9473.00  9472.00
#
# ...

# %%
split=int(0.8*data.shape[0])
train=data.iloc[:split,:]
test=data.iloc[split:,:]

# %%
train_labels=train.iloc[:,-1]
training=train.iloc[:,:63]
test_labels=test.iloc[:,-1]
testing=test.iloc[:,:63]
training=training.drop(columns=['Timestamp'])
testing=testing.drop(columns=['Timestamp'])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0).fit(training,train_labels)

# %%
test_output=clf.predict(testing)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_labels, test_output)-10
# Out:
# 0.905367231638418
